# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Background
#
# Pymaceuticals Inc. is screening for potential treatments for squamous cell carcinoma (SCC), a commonly occurring form of skin cancer.
#
# In its latest study, 249 mice who were identified with SCC tumors received treatment with a range of drug regimens. Over the course of 45 days, tumor development was observed and measured. The purpose of this study was to compare the performance of Pymaceuticals’ drug of interest, Capomulin, against the other treatment regimens.
#
# ### Data Description
#
#  - 9 treament drugs and 1 placebo were test in 249 mice over 45 days.
#  - One mouse was removed from the data due to duplicate measurements.
#  - In the final data set of 248 mice, the ratio of male to female mice was nearly even at 50.4% vs 49.6%, respectively.
#  - The final number of observations in the study totaled 1,880 and the observations per drug ranged from 148 to 230, indicating robust sample sizes for each drug tested.
#  - The starting measurement for each tumor was ~45 mm3 across all tested treatments.
#
# ### Summary Findings
#  - Across the 45-day testing period, Capomulin and Ramicane had the smallest mean tumor volume and the smallest standard deviation, indicating that these 2 drugs were most effective in reducing tumor sizes of the drugs tested.
#
#
#  ![stat%20summary.jpg] <img src="attachment:stat%20summary.jpg" width="400">
#
#
#  - Final tumor volume for 4 drugs, Capomulin, Ramicane, Infubinol, and Ceftamin were further analyzed to determine the data distribution for each drug as well as the presence of outliers.
#      - The median values and inter-quartile-ranges of the final tumor volumes of Capomulin and Ramicane were the lowest, again suggesting that these two drugs were the most effective.
#      - Only Infubinol was shown to have potential outliers.
#
#
#  - The Capomulin treatment data suggest a strong positive relationship exists between tumor size and mouse weight based on a Pearson correlation (r = 0.84).
#
#  - A linear regression model was run on the Capomulin treatment data with mouse weight as the independent variable and tumor size the dependent variable.  The resulting R-squared of .70 indicates that mouse weight explains 70% of the variation in the observed tumor sizes.
#
#  - Based on the Pearson correalation and linear regression R-squared, it is recommended that mouse weight be controlled for during future testing.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Display the mouse_metadata data for preview
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
# Display the study_results data for preview
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single dataset
# EX: school_student_data_df = pd.merge(school_data_df, student_data_df, on=["school_name", "school_name"])
combined_data = pd.merge(mouse_metadata, study_results, on=["Mouse ID", "Mouse ID"])

# Display the data table for preview
combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Check the values of all the columns and see if there are any rows with missing data
combined_data.count()
# Out:
# Mouse ID              1893
# Drug Regimen          1893
# Sex                   1893
# Age_months            1893
# Weight (g)            1893
# Timepoint             1893
# Tumor Volume (mm3)    1893
# Metastatic Sites      1893
# dtype: int64

# %%
# Checking the number of mice.
mouse_ID_total = combined_data["Mouse ID"].unique().size
mouse_ID_total
# Out:
# 249

# %%
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

df2 = combined_data[combined_data.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)]
df2
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
    
g989 = combined_data.loc[combined_data["Mouse ID"] == "g989"]
g989
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

clean_combined_data = combined_data[combined_data["Mouse ID"] != "g989"]

clean_combined_data.to_csv('clean_combined_data.csv')

clean_combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.

mouse_ID_total = clean_combined_data["Mouse ID"].unique().size
mouse_ID_total
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

# Create series to store the summary statistics of the "Tumor Volume" "Drug Regimen"

mean_volume = clean_combined_data.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
median_volume = clean_combined_data.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
var_volume = clean_combined_data.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
std_volume = clean_combined_data.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
sem_volume = clean_combined_data.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]

# %%
# Assemble the resulting series into a single summary DataFrame.

tumor_vol_sumstat = pd.DataFrame({'Mean Tumor Volume':mean_volume, 
                                'Median Tumor Volume':median_volume,    
                                'Variance Tumor Volume' : var_volume,
                                'Std Tumor Volume' : std_volume,
                                'SEM Tumor Volume' : sem_volume
                             })
tumor_vol_sumstat
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Variance Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Std Tumor Volume  SEM Tumor Volume
# Drug Regimen
# Capomulin             4.994774          0.329346
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.

summary_stat_agg = clean_combined_data.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].agg(['mean', 
                                                'median', 'var', 'std', 'sem'])
summary_stat_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen 
# using Pandas.

#,title=("Total Timepoints of Mice Tested by Drug Regimen")

tot_timepoints_by_drug = clean_combined_data.groupby(["Drug Regimen"]).count()["Timepoint"].sort_values(ascending=False)

tot_timepoints_by_drug.plot(kind="bar", ylabel="Total Timepoints of Mice Tested")
# Out:
# <AxesSubplot:xlabel='Drug Regimen', ylabel='Total Timepoints of Mice Tested'>

# %%
# View the Total Timepoints by Drug Regimen
tot_timepoints_by_drug
# Out:
# Drug Regimen
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Placebo      181
# Stelasyn     181
# Ceftamin     178
# Infubinol    178
# Propriva     148
# Name: Timepoint, dtype: int64

# %%
# Group data by Sex and count the IDs for Unique Mice

male_female = clean_combined_data.groupby(["Sex"])["Mouse ID"].nunique()
male_female
# Out:
# Sex
# Female    123
# Male      125
# Name: Mouse ID, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

male_female.plot(kind="pie", autopct="%1.1f%%", ylabel="Sex")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens: 
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

last_timepoint = pd.DataFrame(clean_combined_data.groupby(["Mouse ID"])["Timepoint"].max())
last_timepoint
# Out:
#           Timepoint
# Mouse ID
# a203             45
# a251             45
# a262             45
# a275             45
# a366             30
# ...             ...
# z435             10
# z578             45
# z581             45
# z795             45
# z969             45
#
# [248 rows x 1 columns]

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

last_tp_combined_data = pd.merge(last_timepoint, clean_combined_data, on =["Mouse ID", "Timepoint"])

last_tp_combined_data.to_csv('last_tp_combined_data.csv')

last_tp_combined_data
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Check the data for one example mouse to ensure only the last timepoint is in the dataframe

z969 = last_tp_combined_data.loc[last_tp_combined_data["Mouse ID"] == "z969"]
z969.head(40)
# Out:
#     Mouse ID  Timepoint Drug Regimen   Sex  Age_months  Weight (g)  \
# 247     z969         45     Naftisol  Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 247           73.867845                 4

# %%
# STARTER CODE instructions:
# Put treatments into a list for for loop (and later for plot labels)

# Create empty list to fill with tumor vol data (for plotting)

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    # add subset 
    
    # Determine outliers using upper and lower bounds
    
# OUTPUT:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# STARTER CODE instructions:

# Put treatments into a list for for loop (and later for plot labels)
drugs = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tum_vol = []


# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds

for row in last_tp_combined_data:
    tum_vol = last_tp_combined_data.loc[last_tp_combined_data['Drug Regimen']== drugs]['Tumor Volume (mm3)']

    quantiles = quantile[.25, .5, .75]
    lowerq = quantiles[.25]
    upperq = quantiles[.75]
    IQR = upperq - lowerq
    lowerbound = lowerq - (1.5 * IQR)
    upperbound = upperq + (1.5 * IQR)

# OUTPUT:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/kb/rb5nc0t515n7y9vftjt10s9h0000gn/T/ipykernel_57976/2720078736.py in <module>
#      14
#      15 for row in last_tp_combined_data:
# ---> 16     tum_vol = last_tp_combined_data.loc[last_tp_combined_data['Drug Regimen']== drugs]['Tumor Volume (mm3)']
#      17
#      18     quantiles = quantile[.25, .5, .75]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
# ...

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Determine outliers using upper and lower bounds
# drugs_of_interest are Capomulin, Ramicane, Infubinol, Ceftamin

cap = last_tp_combined_data.loc[last_tp_combined_data['Drug Regimen']== 'Capomulin']['Tumor Volume (mm3)'] 
cap_quantiles = cap.quantile([.25, .5, .75])
cap_lowerq = cap_quantiles[.25]
cap_upperq = cap_quantiles[.75]
cap_IQR = cap_upperq - cap_lowerq
cap_lowerbound = cap_lowerq - (1.5 * cap_IQR)
cap_upperbound = cap_upperq + (1.5 * cap_IQR)

ram = last_tp_combined_data.loc[last_tp_combined_data['Drug Regimen']== 'Ramicane']['Tumor Volume (mm3)'] 
ram_quantiles = ram.quantile([.25, .5, .75])
ram_lowerq = ram_quantiles[.25]
ram_upperq = ram_quantiles[.75]
ram_IQR = ram_upperq - ram_lowerq
ram_lowerbound = ram_lowerq - (1.5 * ram_IQR)
ram_upperbound = ram_upperq + (1.5 * ram_IQR)

inf = last_tp_combined_data.loc[last_tp_combined_data['Drug Regimen']== 'Infubinol']['Tumor Volume (mm3)'] 
inf_quantiles = inf.quantile([.25, .5, .75])
inf_lowerq = inf_quantiles[.25]
inf_upperq = inf_quantiles[.75]
inf_IQR = inf_upperq - inf_lowerq
inf_lowerbound = inf_lowerq - (1.5 * inf_IQR)
inf_upperbound = inf_upperq + (1.5 * inf_IQR)

cef = last_tp_combined_data.loc[last_tp_combined_data['Drug Regimen']== 'Ceftamin']['Tumor Volume (mm3)'] 
cef_quantiles = cef.quantile([.25, .5, .75])
cef_lowerq = cef_quantiles[.25]
cef_upperq = cef_quantiles[.75]
cef_IQR = cef_upperq - cef_lowerq
cef_lowerbound = cef_lowerq - (1.5 * cef_IQR)
cef_upperbound = cef_upperq + (1.5 * cef_IQR)

print(f"Capomulin's potential outliers: {cap.loc[(cap < cap_lowerbound) | (cap > cap_upperbound)]}")
print(f"Ramicane's potential outliers: {ram.loc[(ram < ram_lowerbound) | (ram > ram_upperbound)]}")
print(f"Infubinol's potential outliers: {inf.loc[(inf < inf_lowerbound) | (inf > inf_upperbound)]}")
print(f"Ceftamin's potential outliers: {cef.loc[(cef < cef_lowerbound) | (cef > cef_upperbound)]}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

plt.boxplot([cap, ram, inf, cef], labels = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])
plt.ylabel('Final Tumor Volume (mm3)')
plt.xlabel('Drug Regimen')
plt.title("Boxplot of Data Distributions and Outliers")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# View the Capomulin complete data set to select a mouse
cap_data = combined_data.loc[combined_data['Drug Regimen'] == 'Capomulin']

cap_data.to_csv('cap_data.csv')

cap_data
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
# Check the number of unique mice tested with Capomulin

cap_mice = cap_data["Mouse ID"].unique().size
cap_mice
# Out:
# 25

# %%
# List all the data by mouse ID for Capomulin

avg_weight_by_mouse = cap_data.groupby(["Mouse ID"]).mean()["Weight (g)"]
avg_tum_vol_by_mouse = cap_data.groupby(["Mouse ID"]).mean()["Tumor Volume (mm3)"]

cap_data_by_mouse = pd.DataFrame({'Avg Weight': avg_weight_by_mouse, 
                                'Avg Tumor Volume': avg_tum_vol_by_mouse
                                }) 
cap_data_by_mouse.sort_values(by = 'Avg Weight')
# Out:
#           Avg Weight  Avg Tumor Volume
# Mouse ID
# x401            15.0         36.182040
# y793            17.0         38.506829
# u364            17.0         39.887495
# f966            17.0         36.505973
# t565            17.0         39.328725
# s185            17.0         34.559143
# r554            17.0         36.509212
# m601            17.0         34.847470
# l897            19.0         42.507261
# m957            19.0         39.049816
# g288            19.0         41.990097
# i738            20.0         39.141053
# j246            21.0         43.216925
# b742            21.0         40.083699
# v923            21.0         41.581595
# w914            21.0         41.352452
# l509            21.0         44.434474
# g316            22.0         44.613344
# b128            22.0         41.963636
# j119            23.0         44.465236
# s710            23.0         42.803733
# w150            23.0         41.384825
# i557            24.0         44.805810
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# Show data for mouse s185

s185 = cap_data.loc[cap_data["Mouse ID"] == "s185"]
s185
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# ...

# %%
# Generate a line plot of tumor volume vs. time point for mouse "s185" treated with Capomulin


plt.plot(s185["Timepoint"], s185["Tumor Volume (mm3)"], marker = '*', markerfacecolor='red', markersize=12) 
plt.title("Capomulin Treatment of Mouse S185")
plt.xlabel("Timepoint in Days")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

x_values = cap_data.groupby(['Mouse ID']).mean()["Weight (g)"]
y_values = cap_data.groupby(['Mouse ID']).mean()["Tumor Volume (mm3)"]

plt.scatter(x_values, y_values, marker="o", facecolors="blue", alpha=0.75)

plt.title("Avg Tumor Size vs Avg Mouse Weight for Capomulin Regimen")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3))")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3))')

# %%
# Create series for each mouse treated with Capomulin for plotting
x401 = cap_data.loc[cap_data["Mouse ID"] == "x401"]
y793 = cap_data.loc[cap_data["Mouse ID"] == "y793"]
u364 = cap_data.loc[cap_data["Mouse ID"] == "u364"]
f966 = cap_data.loc[cap_data["Mouse ID"] == "f966"]
t565 = cap_data.loc[cap_data["Mouse ID"] == "t565"]
s185 = cap_data.loc[cap_data["Mouse ID"] == "s185"]
r554 = cap_data.loc[cap_data["Mouse ID"] == "r554"]
m601 = cap_data.loc[cap_data["Mouse ID"] == "m601"]
l897 = cap_data.loc[cap_data["Mouse ID"] == "l897"]
m957 = cap_data.loc[cap_data["Mouse ID"] == "m957"]
g288 = cap_data.loc[cap_data["Mouse ID"] == "g288"]
i738 = cap_data.loc[cap_data["Mouse ID"] == "i738"]
j246 = cap_data.loc[cap_data["Mouse ID"] == "j246"]
b742 = cap_data.loc[cap_data["Mouse ID"] == "b742"]
v923 = cap_data.loc[cap_data["Mouse ID"] == "v923"]
w914 = cap_data.loc[cap_data["Mouse ID"] == "w914"]
l509 = cap_data.loc[cap_data["Mouse ID"] == "l509"]
g316 = cap_data.loc[cap_data["Mouse ID"] == "g316"]
b128 = cap_data.loc[cap_data["Mouse ID"] == "b128"]
j119 = cap_data.loc[cap_data["Mouse ID"] == "j119"]
s710 = cap_data.loc[cap_data["Mouse ID"] == "s710"]
w150 = cap_data.loc[cap_data["Mouse ID"] == "w150"]
i557 = cap_data.loc[cap_data["Mouse ID"] == "i557"]
r157 = cap_data.loc[cap_data["Mouse ID"] == "r157"]
r944 = cap_data.loc[cap_data["Mouse ID"] == "r944"]

# %%
# Plot first 13 mice to determine if tumor volume decreased from starting volume in all mice
plt.plot(x401["Timepoint"], x401["Tumor Volume (mm3)"],label='x401')
plt.plot(y793["Timepoint"], y793["Tumor Volume (mm3)"],label='y793')
plt.plot(u364["Timepoint"], u364["Tumor Volume (mm3)"],label='u364')
plt.plot(f966["Timepoint"], f966["Tumor Volume (mm3)"],label='f966')
plt.plot(t565["Timepoint"], t565["Tumor Volume (mm3)"],label='t565')
plt.plot(s185["Timepoint"], s185["Tumor Volume (mm3)"],label='s185')
plt.plot(r554["Timepoint"], r554["Tumor Volume (mm3)"],label='r554')
plt.plot(m601["Timepoint"], m601["Tumor Volume (mm3)"],label='m601')
plt.plot(l897["Timepoint"], l897["Tumor Volume (mm3)"],label='l897')
plt.plot(m957["Timepoint"], m957["Tumor Volume (mm3)"],label='m957')
plt.plot(g288["Timepoint"], g288["Tumor Volume (mm3)"],label='g288')
plt.plot(i738["Timepoint"], i738["Tumor Volume (mm3)"],label='i738')
plt.plot(j246["Timepoint"], j246["Tumor Volume (mm3)"],label='j246')

plt.title("Capomulin Treatment of 1st 13 Mice")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# Plot last 12 mice to determine if tumor volume decreased from starting volume in all mice
plt.plot(b742["Timepoint"], b742["Tumor Volume (mm3)"],label='b742')
plt.plot(v923["Timepoint"], v923["Tumor Volume (mm3)"],label='v923')
plt.plot(w914["Timepoint"], w914["Tumor Volume (mm3)"],label='w914')
plt.plot(l509["Timepoint"], l509["Tumor Volume (mm3)"],label='l509')
plt.plot(g316["Timepoint"], g316["Tumor Volume (mm3)"],label='g316')
plt.plot(b128["Timepoint"], b128["Tumor Volume (mm3)"],label='b128')
plt.plot(j119["Timepoint"], j119["Tumor Volume (mm3)"],label='j119')
plt.plot(s710["Timepoint"], s710["Tumor Volume (mm3)"],label='s710')
plt.plot(w150["Timepoint"], w150["Tumor Volume (mm3)"],label='w150')
plt.plot(i557["Timepoint"], i557["Tumor Volume (mm3)"],label='i557')
plt.plot(r157["Timepoint"], r157["Tumor Volume (mm3)"],label='r157')
plt.plot(r944["Timepoint"], r944["Tumor Volume (mm3)"],label='r944')

plt.title("Capomulin Treatment of Last 12 Mice")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient for mouse weight and average tumor volume for the Capomulin regimen

corr=round(st.pearsonr(cap_data.groupby(['Mouse ID']).mean()["Weight (g)"],
                       cap_data.groupby(['Mouse ID']).mean()["Tumor Volume (mm3)"])[0],2)
print(f"The Pearson correlation between mouse weight and average tumor volume is {corr}")
# Out:
# The Pearson correlation between mouse weight and average tumor volume is 0.84

# %%
# Calculate the linear regression model for mouse weight and average tumor volume for the Capomulin regimen

x_values = cap_data.groupby(['Mouse ID']).mean()["Weight (g)"]
y_values = cap_data.groupby(['Mouse ID']).mean()["Tumor Volume (mm3)"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")


plt.title("Avg Tumor Size vs Avg Mouse Weight for Capomulin Regimen")
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')

print(f"The R-squared of average mouse weight and  average tumor volume is {rvalue**2}")

plt.show()
# Out:
# The R-squared of average mouse weight and  average tumor volume is 0.7088568047708723
